# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("day.csv")

# %%
train_df1, test_df3 = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_df1, val_df2 = train_test_split(train_df1, test_size=0.1, random_state=42)

# %%
jumlah_data = {
    "Total": len(df),
    "Training": len(train_df1),
    "Validation": len(val_df2),
    "Testing": len(test_df3)
}

print(jumlah_data)
# Out:
# {'Total': 731, 'Training': 525, 'Validation': 59, 'Testing': 147}

# %%
print("\nTraining:")
display(train_df1.head())
# Out:
# Training:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 682      683  2012-11-13       4   1    11        0        2           1
# 250      251  2011-09-08       3   0     9        0        4           1
# 336      337  2011-12-03       4   0    12        0        6           0
# 260      261  2011-09-18       3   0     9        0        0           0
# 543      544  2012-06-27       3   1     6        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 682           2  0.343333  0.323225  0.662917   0.342046     327        3767
# 250           3  0.633913  0.555361  0.939565   0.192748     153        1689
# 336           1  0.299167  0.310604  0.612917   0.095783     706        2908
# 260           1  0.507500  0.490537  0.695000   0.178483    1353        2921
# 543           1  0.697500  0.640792  0.360000   0.271775    1077        6258
#
#       cnt
# 682  4094
# 250  1842
# 336  3614
# ...

# %%
print("\nValidation:")
display(val_df2.head())
# Out:
# Validation:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 325      326  2011-11-22       4   0    11        0        2           1
# 410      411  2012-02-15       1   1     2        0        3           1
# 92        93  2011-04-03       2   0     4        0        0           0
# 47        48  2011-02-17       1   0     2        0        4           1
# 508      509  2012-05-23       2   1     5        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 325           3  0.416667  0.421696  0.962500   0.118792      69        1538
# 410           1  0.348333  0.351629  0.531250   0.181600     141        4028
# 92            1  0.378333  0.378767  0.480000   0.182213    1651        1598
# 47            1  0.435833  0.428658  0.505000   0.230104     259        2216
# 508           2  0.621667  0.584612  0.774583   0.102000     766        4494
#
#       cnt
# 325  1607
# 410  4169
# 92   3249
# ...

# %%
print("\nTesting:")
display(test_df3.head())
# Out:
# Testing:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 703      704  2012-12-04       4   1    12        0        2           1
# 33        34  2011-02-03       1   0     2        0        4           1
# 300      301  2011-10-28       4   0    10        0        5           1
# 456      457  2012-04-01       2   1     4        0        0           0
# 633      634  2012-09-25       4   1     9        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 703           1  0.475833  0.469054  0.733750   0.174129     551        6055
# 33            1  0.186957  0.177878  0.437826   0.277752      61        1489
# 300           2  0.330833  0.318812  0.585833   0.229479     456        3291
# 456           2  0.425833  0.417287  0.676250   0.172267    2347        3694
# 633           1  0.550000  0.544179  0.570000   0.236321     845        6693
#
#       cnt
# 703  6606
# 33   1550
# 300  3747
# ...
